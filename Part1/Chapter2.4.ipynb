# %% [markdown]
# ## Chapter2.4 Datalabで様々なグラフ描画

# %%
# !bq load --autodetect testdataset.tips ../datasets/tips.csv

# %% [markdown]
# pandas DataFrameに読み込みます
# <font color="red">**PROJECTID**を書き換えて実行してください</font>

# %%
import pandas as pd

query = """
SELECT * FROM testdataset.tips
"""

df = pd.read_gbq(project_id='PROJECTID', query=query)
# Out:
# Requesting query... ok.
# Job ID: job_f8Rrdm-9JbgrO4PldmBozk5mKTKt
# Query running...
# Query done.
# Cache hit.
#
# Retrieving results...
# Got 244 rows.
#
# Total time taken 1.09 s.
# Finished at 2017-08-06 04:41:07.

# %%
df.head()
# Out:
#    total_bill   tip  gender  smoker   day    time  size
# 0        8.58  1.92    Male    True   Fri   Lunch     1
# 1        3.07  1.00  Female    True   Sat  Dinner     1
# 2       10.07  1.83  Female   False  Thur   Lunch     1
# 3        7.25  1.00  Female   False   Sat  Dinner     1
# 4       23.68  3.31    Male   False   Sun  Dinner     2

# %%
import matplotlib.pyplot as plt

# %%
df.plot()

# %%
import seaborn as sns

sns.lmplot(data=df, x='total_bill', y='tip')

# %%
sns.kdeplot(df.total_bill, df.tip)

# %%
sns.distplot(df.total_bill)

# %%
corr = df.corr()

sns.heatmap(corr)

# %%
sns.pairplot(df, hue='time')
